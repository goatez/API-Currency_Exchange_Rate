# %% [markdown]
# # API Practice
#
# ### Review
# - JSON in Python - First cell
# - JSON in Pandas - Second cell

# %%
import urllib.request, urllib.parse, urllib.error
import json
import pandas as pd

# %%
import xml.etree.ElementTree as ET

input = '''
<stuff>
  <users>
    <user x="2">
      <id>001</id>
      <name>Chuck</name>
    </user>
    <user x="7">
      <id>009</id>
      <name>Brent</name>
    </user>
  </users>
</stuff>'''

# %%
stuff = ET.fromstring(input)
lst = stuff.findall('users/user')
print('User count:', len(lst))
# Out:
# User count: 2

# %%
for item in lst:
#     print('Name', item.find('name').text)
    print('Id', item.find('id').text)
    print('Attribute', item.get('x'))
# Out:
# Id 001
# Attribute 2
# Id 009
# Attribute 7

# %%
stuff = ET.fromstring(input)

lst = stuff.findall('users/user')
print('User count:', len(lst))

lst2 = stuff.findall('user')
print('User count:', len(lst2))
# Out:
# User count: 2
# User count: 0

# %%
for item in stuff.findall('users/user'):
    print('name:', item.find('name').text)
    print('Attribute:', item.get('x'))
# Out:
# name: Chuck
# Attribute: 2
# name: Brent
# Attribute: 7

# %% [markdown]
# ------

# %%
# url + requirements + api key
https://www.alphavantage.co/query?
function=CURRENCY_EXCHANGE_RATE&
from_currency=USD&
to_currency=BTC&
apikey=6DWXECWW9U6OTFRK

# complete URL for USD to Bitcoin rate exchange
https://www.alphavantage.co/query?function=CURRENCY_EXCHANGE_RATE&from_currency=USD&to_currency=JPY&apikey=demo

# %% [markdown]
# ----

# %%
import urllib.request, urllib.parse, urllib.error
import json
import pandas as pd
import os

os.getcwd()
# Out:
# 'C:\\Users\\goat\\Desktop\\309_data'

# %%
# change directory to data if necessary
os.chdir('data')

# %%
url = 'https://www.alphavantage.co/query?function=CURRENCY_EXCHANGE_RATE&from_currency=USD&to_currency=BTC&apikey=6DWXECWW9U6OTFRK'
stuff = urllib.request.urlopen(url)
data = stuff.read().decode()
print('Retrieved', len(data), 'characters')


exr = json.loads(data)

print(json.dumps(exr, indent=4))

from_cur = exr["Realtime Currency Exchange Rate"]["2. From_Currency Name"]
to_cur = exr["Realtime Currency Exchange Rate"]["4. To_Currency Name"]

exrate = exr["Realtime Currency Exchange Rate"]["5. Exchange Rate"]
print('Exchange rate from', from_cur, "to", to_cur+":",exrate )
# Out:
# Retrieved 351 characters
# {
#     "Realtime Currency Exchange Rate": {
#         "1. From_Currency Code": "USD",
#         "2. From_Currency Name": "United States Dollar",
#         "3. To_Currency Code": "BTC",
#         "4. To_Currency Name": "Bitcoin",
#         "5. Exchange Rate": "0.00015300",
#         "6. Last Refreshed": "2018-10-08 04:17:22",
#         "7. Time Zone": "UTC"
#     }
# }
# Exchange rate from United States Dollar to Bitcoin: 0.00015300

# %%
# create dictionary of currency names: currency codes
df = pd.read_csv("currency.csv")
currency = df.set_index('currency_name').transpose().to_dict(orient='index')
currency = currency['currency_code']

# %% [markdown]
# ---

# %%
currency
# Out:
# {'United Arab Emirates Dirham': 'AED',
#  'Afghan Afghani': 'AFN',
#  'Albanian Lek': 'ALL',
#  'Armenian Dram': 'AMD',
#  'Netherlands Antillean Guilder': 'ANG',
#  'Angolan Kwanza': 'AOA',
#  'Argentine Peso': 'ARS',
#  'Australian Dollar': 'AUD',
#  'Aruban Florin': 'AWG',
#  'Azerbaijani Manat': 'AZN',
#  'Bosnia-Herzegovina Convertible Mark': 'BAM',
#  'Barbadian Dollar': 'BBD',
#  'Bangladeshi Taka': 'BDT',
#  'Bulgarian Lev': 'BGN',
#  'Bahraini Dinar': 'BHD',
#  'Burundian Franc': 'BIF',
#  'Bermudan Dollar': 'BMD',
#  'Brunei Dollar': 'BND',
#  'Bolivian Boliviano': 'BOB',
#  'Brazilian Real': 'BRL',
#  'Bahamian Dollar': 'BSD',
#  'Bhutanese Ngultrum': 'BTN',
#  'Botswanan Pula': 'BWP',
#  'Belize Dollar': 'BZD',
#  'Canadian Dollar': 'CAD',
#  'Congolese Franc': 'CDF',
#  'Swiss Franc': 'CHF',
#  'Chilean Unit of Account UF': 'CLF',
#  'Chilean Peso': 'CLP',
#  'Chinese Yuan Offshore': 'CNH',
#  'Chinese Yuan': 'CNY',
#  'Colombian Peso': 'COP',
#  'Cuban Peso': 'CUP',
# ...

# %%
import urllib.request, urllib.parse, urllib.error
import json
import pandas as pd

api = 'https://www.alphavantage.co/query?function=CURRENCY_EXCHANGE_RATE'
apikey = '&apikey=6DWXECWW9U6OTFRK'

while True:
    prompt1 = input('Enter from currency code: ')
    if len(prompt1) < 1: break
#         print('==== Invalid Currency Code - Failure To Retrieve ====')
        
    while True:
        prompt2 = input('Enter to currency code: ')
        if len(prompt2) < 1: break
#             print('==== Invalid Currency Code - Failure To Retrieve ====')
#             break
            
        url = api + '&' + urllib.parse.urlencode({'from_currency': prompt1}) + '&' + urllib.parse.urlencode({'to_currency': prompt2}) + apikey
#         print('Retrieving', url)

        address = urllib.request.urlopen(url)
        data = address.read().decode()
#         print('Retrieved', len(data), 'characters')

#         try:
#             exr = json.loads(data)
#         except:
#             exr = None

#         if not exr or exr['status'] != 'OK':
#             print('==== Failure To Retrieve ====')
#             print(data)
#             continue     

        exr = json.loads(data)
        
        print(json.dumps(exr, indent=4))

        from_cur = exr["Realtime Currency Exchange Rate"]["2. From_Currency Name"]
        to_cur = exr["Realtime Currency Exchange Rate"]["4. To_Currency Name"]

        exrate = exr["Realtime Currency Exchange Rate"]["5. Exchange Rate"]
        print('Exchange rate from', from_cur, "to", to_cur+":",exrate )

# %%
'from_currency='
'&to_currency='
apikey = '&apikey=6DWXECWW9U6OTFRK'

# %%
api = 'https://www.alphavantage.co/query?function=CURRENCY_EXCHANGE_RATE'
apikey = '&apikey=6DWXECWW9U6OTFRK'

prompt1 = input('enter from: ')
prompt2 = input('enter to: ')

url = api + '&' + urllib.parse.urlencode({'from_currency': prompt1}) + '&' + urllib.parse.urlencode({'to_currency': prompt2}) + apikey
print('Retrieving', url)
# Out:
# enter from: USD
# enter to: BTC
# Retrieving https://www.alphavantage.co/query?function=CURRENCY_EXCHANGE_RATE&from_currency=USD&to_currency=BTC&apikey=6DWXECWW9U6OTFRK

# %%
prompt = input("enter the next item, or type done if complete: ")
# Out:
# enter the next item, or type done if complete: done

# %%
import urllib.request, urllib.parse, urllib.error
import json
import pandas as pd

api = 'https://www.alphavantage.co/query?function=CURRENCY_EXCHANGE_RATE'
apikey = '&apikey=6DWXECWW9U6OTFRK'

prompt1 = input('Enter from currency code: ')
prompt2 = input('Enter to currency code: ')

if len(prompt1) > 1 and len(prompt2) > 1:
    #print('==== Invalid Currency Code - Failure To Retrieve ====')

    url = api + '&' + urllib.parse.urlencode({'from_currency': prompt1}) + '&' + urllib.parse.urlencode({'to_currency': prompt2}) + apikey

    address = urllib.request.urlopen(url)
    data = address.read().decode()

#     try:
#         exr = json.loads(data)
#     except:
#         exr = None

#     if not exr or 'status' not in exr or exr['status'] != 'OK':
#         print('==== Failure To Retrieve ====')
#         #print(data)     
#         #continue

    exr = json.loads(data)
    print(json.dumps(exr, indent=4))

    from_cur = exr["Realtime Currency Exchange Rate"]["2. From_Currency Name"]
    to_cur = exr["Realtime Currency Exchange Rate"]["4. To_Currency Name"]

    exrate = exr["Realtime Currency Exchange Rate"]["5. Exchange Rate"]
    print('Exchange rate from', from_cur, "to", to_cur+":",exrate )
# Out:
# Enter from currency code: usd
# Enter to currency code: eur
# {
#     "Realtime Currency Exchange Rate": {
#         "1. From_Currency Code": "USD",
#         "2. From_Currency Name": "United States Dollar",
#         "3. To_Currency Code": "EUR",
#         "4. To_Currency Name": "Euro",
#         "5. Exchange Rate": "0.86790000",
#         "6. Last Refreshed": "2018-10-08 02:03:24",
#         "7. Time Zone": "UTC"
#     }
# }
# Exchange rate from United States Dollar to Euro: 0.86790000

# %%
import os
import urllib.request, urllib.parse, urllib.error
import json
import pandas as pd

df = pd.read_csv("currency.csv")
currency = df.set_index('currency_name').transpose().to_dict(orient='index')

# %%
currency = currency['currency_code']

# %%
currency
# Out:
# {'United Arab Emirates Dirham': 'AED',
#  'Afghan Afghani': 'AFN',
#  'Albanian Lek': 'ALL',
#  'Armenian Dram': 'AMD',
#  'Netherlands Antillean Guilder': 'ANG',
#  'Angolan Kwanza': 'AOA',
#  'Argentine Peso': 'ARS',
#  'Australian Dollar': 'AUD',
#  'Aruban Florin': 'AWG',
#  'Azerbaijani Manat': 'AZN',
#  'Bosnia-Herzegovina Convertible Mark': 'BAM',
#  'Barbadian Dollar': 'BBD',
#  'Bangladeshi Taka': 'BDT',
#  'Bulgarian Lev': 'BGN',
#  'Bahraini Dinar': 'BHD',
#  'Burundian Franc': 'BIF',
#  'Bermudan Dollar': 'BMD',
#  'Brunei Dollar': 'BND',
#  'Bolivian Boliviano': 'BOB',
#  'Brazilian Real': 'BRL',
#  'Bahamian Dollar': 'BSD',
#  'Bhutanese Ngultrum': 'BTN',
#  'Botswanan Pula': 'BWP',
#  'Belize Dollar': 'BZD',
#  'Canadian Dollar': 'CAD',
#  'Congolese Franc': 'CDF',
#  'Swiss Franc': 'CHF',
#  'Chilean Unit of Account UF': 'CLF',
#  'Chilean Peso': 'CLP',
#  'Chinese Yuan Offshore': 'CNH',
#  'Chinese Yuan': 'CNY',
#  'Colombian Peso': 'COP',
#  'Cuban Peso': 'CUP',
# ...

# %%
currency['Euro']
# Out:
# 'EUR'

# %%
# Check if dict contains any entry with key 'test' 
if "United States Dollar" in currency:
    print("Yes key exists in dict")
else:
    print("No key does exists in dict")
# Out:
# Yes key exists in dict

# %%
print(currency.get('Euro'))
# Out:
# EUR

# %%
prompt = input("enter currency: ")

if currency.get(prompt) != None:
    prompt = currency[prompt]
    print("Yes key exists in dict")
    print(prompt)
else:
    print("No key does exist in dict")
# Out:
# enter currency: United States Dollar
# Yes key exists in dict
# USD

# %%
prompt = input("enter currency: ")

if prompt in currency:
    prompt = currency[prompt]
    print("Yes key exists in dict")
    print(prompt)
else:
    print("No key does exists in dict")
# Out:
# enter currency: Euro
# Yes key exists in dict
# EUR
